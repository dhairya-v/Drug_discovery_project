# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 5.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                                           organism  \
# 0                []                                        Coronavirus
# 1                []                                 Feline coronavirus
# 2                []                                 Murine coronavirus
# 3                []                                 Canine coronavirus
# 4                []                                 Bovine coronavirus
# 5                []                             Human coronavirus 229E
# 6                []                             Human coronavirus OC43
# 7                []  Middle East respiratory syndrome-related coron...
# 8                []  Severe acute respiratory syndrome-related coro...
# 9                []  Severe acute respiratory syndrome-related coro...
# 10               []    Severe acute respiratory syndrome coronavirus 2
# 11               []    Severe acute respiratory syndrome coronavirus 2
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[11]
selected_target
# Out:
# 'CHEMBL6067603'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
from os import supports_effective_ids
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(species_group_flag = 'false')

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head()
# Out:
#                                          action_type activity_comment  \
# 0  {'action_type': 'DEGRADER', 'description': 'Bi...             None
# 1  {'action_type': 'DEGRADER', 'description': 'Bi...             None
# 2  {'action_type': 'DEGRADER', 'description': 'Bi...             None
# 3  {'action_type': 'DEGRADER', 'description': 'Bi...             None
# 4  {'action_type': 'DEGRADER', 'description': 'Bi...             None
#
#    activity_id                                activity_properties  \
# 0     25985015  [{'comments': None, 'relation': '=', 'result_f...
# 1     25985016  [{'comments': None, 'relation': '=', 'result_f...
# 2     25985017  [{'comments': None, 'relation': '=', 'result_f...
# 3     25985018  [{'comments': None, 'relation': '=', 'result_f...
# 4     25985019  [{'comments': None, 'relation': '=', 'result_f...
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL5548132  PROTAC activity at CRBN (unknown origin)/eGFP-...
# ...

# %%
df.standard_type.unique()
# Out:
# array(['Activity', 'DC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data_CCD"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data_CCD’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data_CCD"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data_CCD"
# Out:
# total 19
# -rw------- 1 root root 19151 Nov  9 21:15 bioactivity_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#                                          action_type activity_comment  \
# 0  {'action_type': 'DEGRADER', 'description': 'Bi...             None
# 1  {'action_type': 'DEGRADER', 'description': 'Bi...             None
# 2  {'action_type': 'DEGRADER', 'description': 'Bi...             None
# 3  {'action_type': 'DEGRADER', 'description': 'Bi...             None
# 4  {'action_type': 'DEGRADER', 'description': 'Bi...             None
# 5  {'action_type': 'DEGRADER', 'description': 'Bi...             None
# 6  {'action_type': 'DEGRADER', 'description': 'Bi...             None
# 7  {'action_type': 'DEGRADER', 'description': 'Bi...             None
#
#    activity_id                                activity_properties  \
# 0     25985015  [{'comments': None, 'relation': '=', 'result_f...
# 1     25985016  [{'comments': None, 'relation': '=', 'result_f...
# 2     25985017  [{'comments': None, 'relation': '=', 'result_f...
# 3     25985018  [{'comments': None, 'relation': '=', 'result_f...
# ...

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### Alternative method

# %%
selection = ['target_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#   target_chembl_id                                   canonical_smiles  \
# 0    CHEMBL6067603  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 1    CHEMBL6067603  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 2    CHEMBL6067603  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 3    CHEMBL6067603  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 4    CHEMBL6067603  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 5    CHEMBL6067603  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCOc...
# 6    CHEMBL6067603  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 7    CHEMBL6067603  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
#
#   standard_value
# 0           27.6
# 1           26.7
# 2           22.4
# 3           14.7
# 4           10.9
# 5          419.0
# 6          296.0
# 7          431.0

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 1      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 2      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 3      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 4      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 5      CHEMBL5592933  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCOc...
# 6      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 7      CHEMBL5569928  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
#
#   bioactivity_class standard_value
# 0            active           27.6
# 1            active           26.7
# 2            active           22.4
# 3            active           14.7
# 4            active           10.9
# 5            active          419.0
# 6            active          296.0
# ...

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 1      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 2      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 3      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 4      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 5      CHEMBL5592933  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCOc...
# 6      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 7      CHEMBL5569928  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
#
#   standard_value
# 0           27.6
# 1           26.7
# 2           22.4
# 3           14.7
# 4           10.9
# 5          419.0
# 6          296.0
# 7          431.0

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 1      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 2      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 3      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 4      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 5      CHEMBL5592933  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCOc...
# 6      CHEMBL5570662  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
# 7      CHEMBL5569928  C[C@@H](OC(C)(C)C)[C@H](NC(=O)OCc1cccc(OCCCCCC...
#
#   standard_value       0
# 0           27.6  active
# 1           26.7  active
# 2           22.4  active
# 3           14.7  active
# 4           10.9  active
# 5          419.0  active
# 6          296.0  active
# 7          431.0  active

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 32
# -rw-r--r-- 1 root root 19151 Nov  9 21:12 bioactivity_data.csv
# -rw-r--r-- 1 root root  1334 Nov  9 21:27 bioactivity_preprocessed_data.csv
# drwx------ 5 root root  4096 Nov  9 21:12 gdrive
# drwxr-xr-x 1 root root  4096 Nov  5 14:33 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data_CCD"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data_CCD"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
